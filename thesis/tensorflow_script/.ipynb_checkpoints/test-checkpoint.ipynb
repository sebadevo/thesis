# %%
from __future__ import absolute_import, division, print_function

import collections
import functools
import os
import six
import time
import glob
from datetime import datetime
import pickle

import sys
 
 
print("User Current Version:-", sys.version)

import numpy as np
import tensorflow as tf
import tensorflow_federated as tff

tf.compat.v1.enable_v2_behavior()

np.random.seed(0)

# Test the TFF is working:
tff.federated_computation(lambda: 'Hello, World!')()
# Out:
# User Current Version:- 3.9.5 (default, Nov 23 2021, 15:27:38)
# [GCC 9.3.0]
# ---------------------------------------------------------------------------
# UnsupportedOperation                      Traceback (most recent call last)
# <ipython-input-3-9caf99124d0d> in <module>
#      24
#      25 # Test the TFF is working:
# ---> 26 tff.federated_computation(lambda: 'Hello, World!')()
#
# ~/.local/lib/python3.9/site-packages/tensorflow_federated/python/core/impl/computation/computation_impl.py in __call__(self, *args, **kwargs)
#     133   def __call__(self, *args, **kwargs):
#     134     arg = function_utils.pack_args(self._type_signature.parameter, args, kwargs)
# --> 135     return self._context_stack.current.invoke(self, arg)
#     136
#     137   def __hash__(self) -> int:
#
# ~/.local/lib/python3.9/site-packages/tensorflow_federated/python/core/impl/execution_contexts/sync_execution_context.py in invoke(self, comp, arg)
#      65
#      66   def invoke(self, comp, arg):
# ---> 67     return self._async_runner.run_coro_and_return_result(
#      68         self._async_context.invoke(comp, arg))
#
# ~/.local/lib/python3.9/site-packages/tensorflow_federated/python/common_libs/async_utils.py in run_coro_and_return_result(self, coro)
#     221     """Runs coroutine in the managed event loop, returning the result."""
#     222     future = asyncio.run_coroutine_threadsafe(coro, self._event_loop)
# --> 223     return future.result()
#     224
#     225   async def await_coro_and_return_result(self, coro):
#
# /usr/lib/python3.9/concurrent/futures/_base.py in result(self, timeout)
#     443                     raise CancelledError()
#     444                 elif self._state == FINISHED:
# --> 445                     return self.__get_result()
#     446                 else:
#     447                     raise TimeoutError()
#
# /usr/lib/python3.9/concurrent/futures/_base.py in __get_result(self)
#     388         if self._exception:
#     389             try:
# --> 390                 raise self._exception
#     391             finally:
#     392                 # Break a reference cycle with the exception in self._exception
#
# ~/.local/lib/python3.9/site-packages/tensorflow_federated/python/common_libs/retrying.py in retry_coro_fn(*args, **kwargs)
#     107         except Exception as e:  # pylint: disable=broad-except
#     108           if not retry_on_exception_filter(e):
# --> 109             raise e
#     110           retry_wait_ms = min(wait_max_ms, retry_wait_ms * wait_multiplier)
#     111           # asyncio.sleep takes arguments in seconds.
#
# ~/.local/lib/python3.9/site-packages/tensorflow_federated/python/common_libs/retrying.py in retry_coro_fn(*args, **kwargs)
#      97       while True:
#      98         try:
# ---> 99           result = await fn(*args, **kwargs)
#     100           if retry_on_result_filter(result):
#     101             retry_wait_ms = min(wait_max_ms, retry_wait_ms * wait_multiplier)
#
# ~/.local/lib/python3.9/site-packages/tensorflow_federated/python/core/impl/execution_contexts/async_execution_context.py in invoke(self, comp, arg)
#     224         cardinalities = {}
#     225
# --> 226       with self._reset_factory_on_error(self._executor_factory,
#     227                                         cardinalities) as executor:
#     228         py_typecheck.check_type(executor, executor_base.Executor)
#
# /usr/lib/python3.9/contextlib.py in __enter__(self)
#     115         del self.args, self.kwds, self.func
#     116         try:
# --> 117             return next(self.gen)
#     118         except StopIteration:
#     119             raise RuntimeError("generator didn't yield") from None
#
# ~/.local/lib/python3.9/site-packages/tensorflow_federated/python/core/impl/execution_contexts/async_execution_context.py in _reset_factory_on_error(self, ex_factory, cardinalities)
#     188     try:
#     189       # We pass a copy down to prevent the caller from mutating.
# --> 190       yield ex_factory.create_executor({**cardinalities})
#     191     except Exception:
#     192       ex_factory.clean_up_executor({**cardinalities})
#
# ~/.local/lib/python3.9/site-packages/tensorflow_federated/python/core/impl/executor_stacks/python_executor_stacks.py in create_executor(self, cardinalities)
#     106     if ex is not None:
#     107       return ex
# --> 108     ex = self._executor_stack_fn(cardinalities)
#     109     py_typecheck.check_type(ex, executor_base.Executor)
#     110     self._executors[key] = ex
#
# ~/.local/lib/python3.9/site-packages/tensorflow_federated/python/core/backends/native/execution_contexts.py in stack_fn(cardinalities)
#     552     if cardinalities.get(placements.CLIENTS) is None:
#     553       cardinalities[placements.CLIENTS] = default_num_clients
# --> 554     stub = service_manager.get_stub()
#     555     ex = remote_executor.RemoteExecutor(stub)
#     556     ex.set_cardinalities(cardinalities)
#
# ~/.local/lib/python3.9/site-packages/tensorflow_federated/python/core/backends/native/execution_contexts.py in get_stub(self)
#     536         self._process.wait()
#     537       # Start a process and block til the associated stub is ready.
# --> 538       process, port = start_process()
#     539       target = f'localhost:{port}'
#     540       channel = grpc.insecure_channel(target, _GRPC_CHANNEL_OPTIONS)
#
# ~/.local/lib/python3.9/site-packages/tensorflow_federated/python/core/backends/native/execution_contexts.py in start_process()
#     501     ]
#     502     logging.debug('Starting TFF C++ server on port: %s', port)
# --> 503     return subprocess.Popen(args, stdout=sys.stdout, stderr=sys.stderr), port
#     504
#     505   class ServiceManager():
#
# /usr/lib/python3.9/subprocess.py in __init__(self, args, bufsize, executable, stdin, stdout, stderr, preexec_fn, close_fds, shell, cwd, env, universal_newlines, startupinfo, creationflags, restore_signals, start_new_session, pass_fds, user, group, extra_groups, encoding, errors, text, umask)
#     827         (p2cread, p2cwrite,
#     828          c2pread, c2pwrite,
# --> 829          errread, errwrite) = self._get_handles(stdin, stdout, stderr)
#     830
#     831         # We wrap OS handles *before* launching the child, otherwise a
#
# /usr/lib/python3.9/subprocess.py in _get_handles(self, stdin, stdout, stderr)
#    1596             else:
#    1597                 # Assuming file-like object
# -> 1598                 c2pwrite = stdout.fileno()
#    1599
#    1600             if stderr is None:
#
# UnsupportedOperation: fileno
